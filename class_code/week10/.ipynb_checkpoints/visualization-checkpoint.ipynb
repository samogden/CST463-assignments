# %%
import tensorflow as tf
import keras as keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load and preprocess the image
img_path = 'nico.jpeg'  # Replace with your image path
img = keras.preprocessing.image.load_img(img_path, target_size=(224, 224))  # Adjust target_size to your model's input size
img_array = keras.preprocessing.image.img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Create batch dimension
img_tensor = keras.applications.vgg16.preprocess_input(img_array)  # Preprocess image for the specific model

# %%
model = keras.applications.vgg16.VGG16()
# Out:
# 2024-10-30 09:41:29.651200: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2024-10-30 09:41:29.651223: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-10-30 09:41:29.651227: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-10-30 09:41:29.651240: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-30 09:41:29.651249: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Visualize Filter Output

# %%
def show_filter(i):
    plt.imshow(model.layers[2].get_weights()[0][:,:,i,i], cmap='grey')

# %%
show_filter(0)

# %%
show_filter(1)

# %%
show_filter(2)

# %%
show_filter(3)

# %%
# Get the first 8 layers of the model
layer_outputs = [layer.output for layer in model.layers[:8]]

# Build a new model that only produces outputs for the 8 layers
activation_model = keras.models.Model(
  inputs=model.input,
  outputs=layer_outputs
)

# Get outputs of the first 8 layers
activations = activation_model.predict(img_tensor)

# Display activations for the first three layers
for layer_num in range(7)[1:]:  # Change to view more or fewer layers
  layer_activations = activations[layer_num]
  print(f"Layer {layer_num + 1} activations shape: {layer_activations.shape}")
  
  # Remove the batch dimension
  layer_activations = layer_activations[0]
  
  # Determine the grid size (e.g., 6x6 for 32 filters)
  num_filters = layer_activations.shape[-1]
  grid_size = int(np.ceil(np.sqrt(num_filters)))
  
  plt.figure(figsize=(30, 30))
  
  for i in range(num_filters)[:5]:
    ax = plt.subplot(grid_size, grid_size, i + 1)
    ax.set_xticks([])
    ax.set_yticks([])
    plt.imshow(layer_activations[:, :, i], cmap='viridis')
  
  plt.tight_layout()
  plt.show()
# Out:
# 2024-10-30 09:41:31.350904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# Layer 2 activations shape: (1, 224, 224, 64)
# Layer 3 activations shape: (1, 224, 224, 64)
# Layer 4 activations shape: (1, 112, 112, 64)
# Layer 5 activations shape: (1, 112, 112, 128)
# Layer 6 activations shape: (1, 112, 112, 128)
# Layer 7 activations shape: (1, 56, 56, 128)
